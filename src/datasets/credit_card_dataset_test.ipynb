# %%
from credit_card_dataset import CreditCardDataset

# %%
data = CreditCardDataset()

# %%
data.get_data()
# Out:
# {'train_labels': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'val_labels': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'test_labels': array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  'train_features': array([[-9.50131941e-01, -1.60956399e-01,  1.77591055e+00, ...,
#           4.46669968e-02,  5.91474646e-02,  3.43401946e+00],
#         [ 1.81625770e+00, -7.97802759e-01, -4.60474878e-01, ...,
#          -2.48262685e-04, -4.28398387e-02,  4.44172141e+00],
#         [ 1.99125930e+00, -4.76710862e-01, -3.02106082e+00, ...,
#          -1.82122313e-01, -9.23798323e-02,  4.70048946e+00],
#         ...,
#         [-5.23164969e-01, -1.00021409e-01,  8.92965542e-01, ...,
#          -1.78416835e-01, -1.37169264e-01,  4.61433803e+00],
#         [ 1.99256152e+00, -5.01777779e-01, -5.07759940e-01, ...,
#           2.57404744e-02, -5.77446235e-02, -6.90775528e+00],
#         [ 1.12767494e+00, -5.68820805e-01, -6.89912065e-01, ...,
# ...
